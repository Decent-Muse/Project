# %% [markdown]
# # Importing required libraries
# - pandas for segregating and cleaning the data
# - numpy for array handling
#
# ### Issues faced
# - datetime in pandas and tensorflow (*which has to be added*)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import xlrd
import csv

# %%
# file_location = 'BUSYv1.csv'
file_location = 'BUSY7246fb6.csv'
df = pd.read_csv(file_location, sep='|', names=['POS_Application_Name','STOREID','MACID','BILLNO','BARCODE','GUID','CREATED_STAMP','CAPTURED_WINDOW','UPDATE_STAMP'])
barcode_size_corrected_df = df[(df['BARCODE'].str.len() == 12) | (df['BARCODE'].str.len() == 13) | (df['BARCODE'].str.len() == 8)]
no_capture_window = barcode_size_corrected_df[['POS_Application_Name','STOREID','BARCODE','GUID','CREATED_STAMP']]
barcode_pattern = '^[0-9]*$'
barcode_rectified = no_capture_window[no_capture_window['BARCODE'].str.contains(barcode_pattern)]
len(barcode_rectified.index)
# Out:
# 56513

# %%
items_sold = barcode_rectified['BARCODE'].value_counts()
print(items_sold[:5])
# Out:
# 8901030564185    668
# 8901030534898    425
# 8901058842722    363
# 8901030341663    300
# 8901030627378    295
# Name: BARCODE, dtype: int64

# %% [markdown]
# #### Datatype issue
#
# Here BARCODE and CREATED_STAMP have the datatype of **object** which is analogous to **string** in native python

# %%
print('barcode_rectified.BARCODE.dtype:\t' + str(barcode_rectified.BARCODE.dtype))
print('barcode_rectified.CREATED_STAMP.dtype:\t' + str(barcode_rectified.CREATED_STAMP.dtype))
# Out:
# barcode_rectified.BARCODE.dtype:	object
# barcode_rectified.CREATED_STAMP.dtype:	object

# %% [markdown]
# #### Barcode Rectified
# Using
# ```python
# pd.to_datetime(<df>, format='<shell format>')
# ```
# we have changed the CREATED_STAMP attribute from object to datetime Dtype

# %%
barcode_rectified['CREATED_STAMP'] = pd.to_datetime(barcode_rectified['CREATED_STAMP'], format='%Y-%m-%d %H:%M:%S')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print('barcode_rectified.CREATED_STAMP.dtype:\t' + str(barcode_rectified.CREATED_STAMP.dtype))
# Out:
# barcode_rectified.CREATED_STAMP.dtype:	datetime64[ns]

# %% [raw]
# barcode_rectified.CREATED_STAMP[:15]

# %% [raw]
# ### BARCODE datatype rectified
# Barcode is now in int64 format (changed from object)

# %% [raw]
# # barcode_rectified.BARCODE = barcode_rectified.BARCODE.astype(str).astype(float)

# %% [raw]
# print(barcode_rectified.BARCODE.dtype)

# %% [raw]
# ## Converting to numpy array
# use pandas.DataFrame.as_matrix(list) to convert pandas dataframe to a numpy array, so that it can be used for analysis

# %% [raw]
# barcodes = pd.DataFrame.as_matrix(barcode_rectified['BARCODE'])

# %% [raw]
# print(type(barcodes))

# %% [raw]
# created_stamps = pd.DataFrame.as_matrix(barcode_rectified['CREATED_STAMP'])
# print(type(created_stamps))

# %% [raw]
# print(np.dtype(barcodes[0]))

# %% [raw]
# print(np.dtype(created_stamps[0]))

# %% [raw]
# barcode_rectified['CREATED_STAMP'] = barcode_rectified['CREATED_STAMP'].dt.strftime('%Y%m%d')

# %% [raw]
# barcode_rectified['CREATED_STAMP'][:10]

# %% [raw]
# barcode_rectified.CREATED_STAMP = barcode_rectified.CREATED_STAMP.astype(str).astype(float)

# %% [raw]
# barcode_rectified

# %%
# making a COPY for joins and other operations (just to change tha name)
busy_df = barcode_rectified.copy(deep=True)

# Loading the product master DataFrame
pm_df = pd.read_excel('ProductMaster404b8b3.xlsx', header = 0)

pm_df
# Out:
#        COMPANY_CODE CATEGORY_DESC        SUBCATEGORY_DESC  BRAND_DESC  \
# 0               HUL           PFW          Washing Powder         Rin
# 1               HUL           PFW          Washing Powder         Rin
# 2               HUL           CPD         Instant Noodles       Knorr
# 3               HUL           CPD         Instant Noodles       Knorr
# 4               HUL           MPW      Personal Wash Bars    Lifebuoy
# 5               HUL           PPW      Personal Wash Bars       PEARS
# 6               HUL           CPD         Instant Noodles       Knorr
# 7               HUL          Skin                Fairness       Ponds
# 8               HUL           CPD          Ketchup-Sauces      Kissan
# 9               HUL          Oral              Toothpaste   Pepsodent
# 10              HUL           MFW          Washing Powder       Wheel
# 11              HUL           MFW          Washing Powder       Wheel
# 12              HUL           MFW          Washing Powder       Wheel
# 13              HUL           MFW          Washing Powder       Wheel
# 14              HUL           PFW           Pre Post Wash     Comfort
# 15              HUL           PFW          Washing Powder         Rin
# 16              HUL           PFW          Washing Powder         Rin
# 17              HUL   PPW Liquids                Handwash    Lifebuoy
# 18              HUL   PPW Liquids                Handwash    Lifebuoy
# 19              HUL          Oral              Toothpaste   Pepsodent
# 20              HUL          Oral              Toothpaste   Pepsodent
# 21              HUL           PPW      Personal Wash Bars      Rexona
# 22              HUL          Skin                Fairness       Ponds
# 23              HUL          Skin                Fairness       Ponds
# 24              HUL           MFW          Detergent Bars       Wheel
# 25              HUL   PPW Liquids                Handwash    Lifebuoy
# 26              HUL           PFW          Washing Powder  Surf Excel
# 27              HUL           PFW          Washing Powder         Rin
# 28              HUL           PFW          Washing Powder         Rin
# 29              HUL           PFW          Washing Powder         Rin
# ...             ...           ...                     ...         ...
# 151806          NaN        OTHERS                     NaN         NaN
# 151807          NaN        OTHERS                     NaN         NaN
# 151808          NaN     HOUSEHOLD                     NaN         NaN
# 151809          NaN          SKIN                     NaN         NaN
# 151810          NaN      TOILETRY  SHAVING BLADE & RAZORS    GILLETTE
# 151811          NaN          HAIR                     NaN         NaN
# 151812          NaN     HOUSEHOLD                     NaN         NaN
# 151813          NaN   PACKED FOOD            BASMATI RICE       AMIRA
# 151814          NaN          SKIN               FACE WASH        OLAY
# 151815          NaN        OTHERS                     NaN         NaN
# 151816          NaN     DEODORANT                     NaN         NaN
# 151817          NaN      BISCUITS                     NaN         NaN
# 151818          NaN     HOUSEHOLD                     NaN         NaN
# 151819          NaN   PACKED FOOD                     NaN         NaN
# 151820          NaN        OTHERS                     NaN         NaN
# 151821          NaN        OTHERS                     NaN         NaN
# 151822          NaN        OTHERS  SHAVING BLADE & RAZORS    GILLETTE
# 151823          NaN        OTHERS                     NaN         NaN
# 151824          NaN        OTHERS                     NaN         NaN
# 151825          NaN        OTHERS                     NaN         NaN
# 151826          NaN        OTHERS                     NaN         NaN
# 151827          NaN   PACKED FOOD                     NaN         NaN
# 151828          NaN        OTHERS                     NaN         NaN
# 151829          NaN        COFFEE                     NaN         NaN
# 151819  PACKED FOOD                             PACKED FOOD      8908003450018
# 151820       OTHERS                                  OTHERS       798295569288
# 151821       OTHERS                                  OTHERS       891030348860
# 151822       OTHERS                       GILLETTE PRESTO -      4902430648912
# 151823       OTHERS                                  OTHERS      8902456503239
# 151824       OTHERS                                  OTHERS  89018901030436992
# 151825       OTHERS                                  OTHERS      8902089041191
# 151826       OTHERS                                  OTHERS         6000610923
# 151827  PACKED FOOD                             PACKED FOOD      8906021910040
# 151828       OTHERS                                  OTHERS      8906027949716
# 151829       COFFEE                                  COFFEE      8901058817140
# 151830       OTHERS                                  OTHERS      8901713027754
# 151831       OTHERS                                  OTHERS      8904039471348
# 151832       OTHERS                                  OTHERS      8904063258861
# 151833       OTHERS                                  OTHERS      8901440202882
# 151834       OTHERS                                  OTHERS       846597032020
# 151835          OIL                                     OIL      8908002040821
#
# [151836 rows x 7 columns]

# %%
# Making the BARCODE as object (String)
busy_df.BARCODE = busy_df.BARCODE.astype('int')
# busy_df

# Joining the two DataFrames based on the barcodes and extracting only category_desc, subcategory_desc, brand_desc and basepack_desc
joined_df = busy_df.join(pm_df.set_index('BARCODE'), on='BARCODE', how='inner', sort=False)

# print(joined_df.BARCODE.dtype)
# print(busy_df.BARCODE.dtype)
# print(pm_df.BARCODE.dtype)
joined_df
# Out:
#        POS_Application_Name        STOREID        BARCODE  \
# 1                      BUSY  DEL0000001446  8901399058561
# 13695                  BUSY  DEL0000001446  8901399058561
# 24018                  BUSY  DEL0000001446  8901399058561
# 43420                  BUSY  DEL0000001446  8901399058561
# 71814                  BUSY  DEL0000001446  8901399058561
# 115762                 BUSY  DEL0000001446  8901399058561
# 122086                 BUSY  DEL0000001446  8901399058561
# 136645                 BUSY  DEL0000001446  8901399058561
# 358903                 BUSY  DEL0000001446  8901399058561
# 359028                 BUSY  DEL0000001446  8901399058561
# 402712                 BUSY  DEL0000001446  8901399058561
# 406565                 BUSY  DEL0000001446  8901399058561
# 440470                 BUSY  DEL0000001446  8901399058561
# 440471                 BUSY  DEL0000001446  8901399058561
# 2                      BUSY  DEL0000001446  8901030349751
# 3127                   BUSY  DEL0000001446  8901030349751
# 6048                   BUSY  DEL0000001446  8901030349751
# 15293                  BUSY  DEL0000001446  8901030349751
# 17129                  BUSY  DEL0000001446  8901030349751
# 24908                  BUSY  DEL0000001446  8901030349751
# 36402                  BUSY  DEL0000001446  8901030349751
# 48383                  BUSY  DEL0000001446  8901030349751
# 48771                  BUSY  DEL0000001446  8901030349751
# 51437                  BUSY  UPR0000002773  8901030349751
# 58382                  BUSY  DEL0000001446  8901030349751
# 58383                  BUSY  DEL0000001446  8901030349751
# 68906                  BUSY  DEL0000001446  8901030349751
# 77243                  BUSY  DEL0000001446  8901030349751
# 80669                  BUSY  DEL0000001446  8901030349751
# 80670                  BUSY  DEL0000001446  8901030349751
# ...                     ...            ...            ...
# 452663                 BUSY  DEL0000001446  4902430742054
# 452664                 BUSY  DEL0000001446  4902430742054
# 452667                 BUSY  DEL0000001446  4902430742054
# 452689                 BUSY  DEL0000001446  8904018300010
8901044470694    2017-03-30    PACKED FOOD      SYRUPS & SQUASHES
# 455941  8901044470694    2017-03-01    PACKED FOOD      SYRUPS & SQUASHES
# 452738  8908002984576    2017-03-30         OTHERS                    NaN
# 453028  8901030632082    2017-03-30            PFW         Washing Powder
# 453143  8901248104067    2017-03-30           HAIR               HAIR OIL
# 453595  8902102161806    2017-03-30         OTHERS                    NaN
# 453736  8902102197423    2017-03-30      HOUSEHOLD     MOSQUITO REPELLENT
# 453742  8902102197423    2017-03-30      HOUSEHOLD     MOSQUITO REPELLENT
# 454002  8901396140108    2017-03-30         OTHERS         FLOOR CLEANERS
# 455940  8901138825881    2017-03-01           SOAP              BABY SOAP
# 456019  8901138512972    2017-03-01         OTHERS  HAIR CARE ACCESSORIES
# 458948  8908001158572    2017-03-10      DEODORANT               MENS DEO
# 460055   806360550809    2017-03-10           SKIN              FACE WASH
# 461251  8901030614897    2017-03-10    PPW Liquids               Handwash
# 461340  8901012111116    2017-03-10  BABY PRODUCTS            BABY POWDER
# 461350   806360011942    2017-03-10         OTHERS                    NaN
# 461351   806360011942    2017-03-10         OTHERS                    NaN
# 461352   806360011942    2017-03-10         OTHERS                    NaN
#
#                BRAND_DESC       BASEPACK
# 1                 SANTOOR           SOAP
# 13695             SANTOOR           SOAP
# 24018             SANTOOR           SOAP
# 43420             SANTOOR           SOAP
# 71814             SANTOOR           SOAP
# 115762            SANTOOR           SOAP
# 122086            SANTOOR           SOAP
# 136645            SANTOOR           SOAP
# 358903            SANTOOR           SOAP
# 359028            SANTOOR           SOAP
# 402712            SANTOOR           SOAP
# 406565            SANTOOR           SOAP
# 440470            SANTOOR           SOAP
# 440471            SANTOOR           SOAP
# 2              Surf Excel          16020
# 3127           Surf Excel          16020
# 6048           Surf Excel          16020
# 15293          Surf Excel          16020
# 17129          Surf Excel          16020
# 24908          Surf Excel          16020
# 36402          Surf Excel          16020
# 48383          Surf Excel          16020
# 48771          Surf Excel          16020
# 51437          Surf Excel          16020
# 58382          Surf Excel          16020
# 58383          Surf Excel          16020
# 68906          Surf Excel          16020
# 77243          Surf Excel          16020
# 80669          Surf Excel          16020
# 80670          Surf Excel          16020
# ...                   ...            ...
# 452663                NaN         OTHERS
# 452664                NaN         OTHERS
# 452667                NaN         OTHERS
# 452689            MEDIMIX         OTHERS
# 452714              MAPRO    PACKED FOOD
# 452715              MAPRO    PACKED FOOD
# 452716              MAPRO    PACKED FOOD
# 452717              MAPRO    PACKED FOOD
# 452718              MAPRO    PACKED FOOD
# 452719              MAPRO    PACKED FOOD
# 452720              MAPRO    PACKED FOOD
# 452721              MAPRO    PACKED FOOD
# 452722              MAPRO    PACKED FOOD
# 455941              MAPRO    PACKED FOOD
# 452738                NaN         OTHERS
# 453028                Rin          16041
# 453143             HIMANI           HAIR
# 453595                NaN         OTHERS
# 453736               MAXO      HOUSEHOLD
# 453742               MAXO      HOUSEHOLD
# 454002              LIZOL         OTHERS
# 455940           HIMALAYA           SOAP
# 456019           HIMALAYA         OTHERS
# 458948               FOGG      DEODORANT
# 460055      LOTUS HERBALS           SKIN
# 461251           Lifebuoy          15121
# 461340  JOHNSON & JOHNSON  BABY PRODUCTS
# 461350                NaN         OTHERS
# 461351                NaN         OTHERS
# 461352                NaN         OTHERS
#
# [43317 rows x 6 columns]

# %%
# Adding week number column
joined_df['WEEK_NUM'] = joined_df['CREATED_STAMP'].dt.week
joined_df['DAY_NUM'] = joined_df['CREATED_STAMP'].dt.dayofyear

joined_df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 455940  8901138825881    2017-03-01           SOAP              BABY SOAP
# 456019  8901138512972    2017-03-01         OTHERS  HAIR CARE ACCESSORIES
# 458948  8908001158572    2017-03-10      DEODORANT               MENS DEO
# 460055   806360550809    2017-03-10           SKIN              FACE WASH
# 461251  8901030614897    2017-03-10    PPW Liquids               Handwash
# 461340  8901012111116    2017-03-10  BABY PRODUCTS            BABY POWDER
# 461350   806360011942    2017-03-10         OTHERS                    NaN
# 461351   806360011942    2017-03-10         OTHERS                    NaN
# 461352   806360011942    2017-03-10         OTHERS                    NaN
#
#                BRAND_DESC       BASEPACK  WEEK_NUM  DAY_NUM
# 1                 SANTOOR           SOAP        52        1
# 13695             SANTOOR           SOAP         1        2
# 24018             SANTOOR           SOAP         4       25
# 43420             SANTOOR           SOAP         1        4
# 71814             SANTOOR           SOAP         1        8
# 115762            SANTOOR           SOAP         2       13
# 122086            SANTOOR           SOAP         2       14
# 136645            SANTOOR           SOAP         3       16
# 358903            SANTOOR           SOAP        10       71
# 359028            SANTOOR           SOAP        10       71
# 402712            SANTOOR           SOAP        12       82
# 406565            SANTOOR           SOAP        12       83
# 440470            SANTOOR           SOAP        13       87
# 440471            SANTOOR           SOAP        13       87
# 2              Surf Excel          16020        52        1
# 3127           Surf Excel          16020        52        1
# 6048           Surf Excel          16020        52        1
# 15293          Surf Excel          16020         1        2
# 17129          Surf Excel          16020         1        2
# 24908          Surf Excel          16020         1        3
# 36402          Surf Excel          16020         8       55
# 48383          Surf Excel          16020         7       46
# 48771          Surf Excel          16020         7       46
# 51437          Surf Excel          16020         6       41
# 58382          Surf Excel          16020         1        6
# 58383          Surf Excel          16020         1        6
# 68906          Surf Excel          16020         1        8
# 77243          Surf Excel          16020         9       62
# 80669          Surf Excel          16020        12       82
# 80670          Surf Excel          16020        12       82
# ...                   ...            ...       ...      ...
# 452663                NaN         OTHERS        13       89
# 452664                NaN         OTHERS        13       89
# 452667                NaN         OTHERS        13       89
# 452689            MEDIMIX         OTHERS        13       89
# 452714              MAPRO    PACKED FOOD        13       89
# 452715              MAPRO    PACKED FOOD        13       89
# 452716              MAPRO    PACKED FOOD        13       89
# 452717              MAPRO    PACKED FOOD        13       89
# 452718              MAPRO    PACKED FOOD        13       89
# 452719              MAPRO    PACKED FOOD        13       89
# 452720              MAPRO    PACKED FOOD        13       89
# 452721              MAPRO    PACKED FOOD        13       89
# 452722              MAPRO    PACKED FOOD        13       89
# 455941              MAPRO    PACKED FOOD         9       60
# 452738                NaN         OTHERS        13       89
# 453028                Rin          16041        13       89
# 453143             HIMANI           HAIR        13       89
# 453595                NaN         OTHERS        13       89
# 453736               MAXO      HOUSEHOLD        13       89
# 453742               MAXO      HOUSEHOLD        13       89
# 454002              LIZOL         OTHERS        13       89
# 455940           HIMALAYA           SOAP         9       60
# 456019           HIMALAYA         OTHERS         9       60
# 458948               FOGG      DEODORANT        10       69
# 460055      LOTUS HERBALS           SKIN        10       69
# 461251           Lifebuoy          15121        10       69
# 461340  JOHNSON & JOHNSON  BABY PRODUCTS        10       69
# 461350                NaN         OTHERS        10       69
# 461351                NaN         OTHERS        10       69
# 461352                NaN         OTHERS        10       69
#
# [43317 rows x 8 columns]

# %%
# Removing the category "Others" so that association rule mining using Apriori

# %%
no_of_weeks = 53;
joined_df_copy = joined_df.copy(deep=True)

with open('weekly_data.csv', 'w') as weekly_file:
    weekly_csv = csv.writer(weekly_file)
    for x in range(1,no_of_weeks):
        weekly_df = joined_df_copy.where(joined_df_copy.WEEK_NUM == x)
        weekly_data = weekly_df['CATEGORY_DESC'].tolist()
        weekly_data = [x for x in weekly_data if not((str(x)=='nan' or str(x)=='OTHERS'))]
        weekly_csv.writerow(list(set(weekly_data)))

# %%
no_of_days = 31+28+31;
joined_df_copy = joined_df.copy(deep=True)

with open('daily_data.csv', 'w') as daily_file:
    daily_csv = csv.writer(daily_file)
    for x in range(1,no_of_days):
        daily_df = joined_df_copy.where(joined_df_copy.DAY_NUM == x)
        daily_data = daily_df['CATEGORY_DESC'].tolist()
        daily_data = [x for x in daily_data if not((str(x)=='nan' or str(x)=='OTHERS'))]
        daily_csv.writerow(list(set(daily_data)))

# %%
datas = ["", 'Divyaksh','Shukla','']
list(filter(None, datas))
# Out:
# ['Divyaksh', 'Shukla']

# %% [markdown]
# # TensorFlow training
#
# - open source tool to provide regression models
# - Here, we used python to analyse the data
#
# #### xlrd
# - to extract data from xls

# %%
import tensorflow as tf
import xlrd

rng = np.random

data_file = "new3.xls"
epochs = 100
display_step = 50

dfile = xlrd.open_workbook(data_file, encoding_override="utf-8")
sheet = dfile.sheet_by_index(0)
data = np.asarray([sheet.row_values(i)for i in range(1, sheet.nrows)])
new_data = np.hsplit(data , 2)
# print(new_data[0])

# %% [markdown]
# **barcodes** are in new_data[0]
# **created_stamps** are in new_data[1]

# %%
barcode = new_data[0]
created_stamps = new_data[1]

# %%
####creating placeholders

BARCODE =tf.placeholder(tf.float32,name="BARCODE")
CREATED_STAMP =tf.placeholder(tf.float32,name="CREATED_STAMP")

####creating weight and bias, initialized to 0

w =tf.Variable(rng.randn(),name="BARCODE")
b =tf.Variable(rng.randn(),name="CREATED_STAMP")

Y_pred = BARCODE * w + b

#### Mean squared error
cost = tf.reduce_sum(tf.pow(Y_pred-CREATED_STAMP, 2))/(2*n_samples)

#loss = tf.square(CREATED_STAMP-Y_pred, name="loss")

opt = tf.train.GradientDescentOptimizer(learning_rate = 0.001).minimize(cost)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for epoch in range(epochs):
        for x, y in data:
            sess.run(opt, feed_dict={BARCODE: x, CREATED_STAMP: y})

        # Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={BARCODE: x, CREATED_STAMP: y})
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "w=", sess.run(w), "b=", sess.run(b))

    w_value, b_value = sess.run([w, b])
    print("Optimization finished!!")
    training_cost = sess.run(cost, feed_dict={BARCODE: x, CREATED_STAMP: y})
    print("Training cost=", training_cost, "w=", sess.run(w), "b=", sess.run(b), '\n')

    # Graphic display
    plt.plot(x, y, 'ro', label='barcode vs timestamp')
    plt.plot(x, sess.run(w) * x + sess.run(b), label='Fitted line')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Graphic Data
#
# The data is plotted on a matplotlib library.
